# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://google.com")

# %%
elem = driver.find_element(By.NAME, "q")
elem.clear()
elem.send_keys("علی بیگدلی")
elem.send_keys(Keys.ENTER)

# %%
result = driver.find_element(By.ID,"search")
html_src = driver.page_source
# html_src

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_src, 'html.parser')

# %%
links = soup.find_all("a")

# %%
links
# Out:
# [<a href="/search?q=%D8%B9%D9%84%DB%8C+%D8%A8%DB%8C%DA%AF%D8%AF%D9%84%DB%8C&amp;sca_esv=6965cced8725ff61&amp;gbv=1&amp;sei=-aBHZqCjIaX97_UPjtO68AI">here</a>,
#  <a class="gyPpGe" data-ved="0ahUKEwjgg5_Ap5WGAxWl_rsIHY6pDi4Q67oDCAU" jsaction="i3viod" jsname="BKxS1e" role="link" tabindex="0">Skip to main content</a>,
#  <a class="o8xTWc gyPpGe" href="#" jsaction="xoizsc" jsname="PwyVob" role="link">Turn off continuous scrolling</a>,
#  <a class="wxIowe kur4we gyPpGe" href="#" jsaction="XZ94se" jsname="BzS6B" role="link">Turn on continuous scrolling</a>,
#  <a class="gyPpGe" href="https://support.google.com/websearch/answer/181196?hl=en-IR" jsname="KI37ad" ping="/url?sa=t&amp;source=web&amp;rct=j&amp;url=https://support.google.com/websearch/answer/181196%3Fhl%3Den-IR&amp;ved=0ahUKEwjgg5_Ap5WGAxWl_rsIHY6pDi4QwcMDCAc&amp;bl=cDLi&amp;opi=89978449">Accessibility help</a>,
# ...

# %%
links = soup.find_all("a")
cites = soup.find_all("cite")

for tag in cites:
    # print(tag.get("href"))
    # print(tag.text)
    if tag.text =="https://thealibigdeli.ir":
        print(tag)
# Out:
# <cite class="tjvcx GvPZzd dTxz9 cHaqb" role="text">https://thealibigdeli.ir</cite>
# <cite class="tjvcx GvPZzd dTxz9 cHaqb" role="text" style="padding-right:0">https://thealibigdeli.ir</cite>

# %%
target = driver.find_element(By.XPATH ,'//*[@id="rso"]/div[3]/div/div/div/div[1]/div/div/span/a/h3/span')
target.click()

# %%
full_name_elem = driver.find_element(By.NAME,"name").send_keys("str")
driver.find_element(By.XPATH ,'//*[@id="rso"]/div[3]/div/div/div/div[1]/div/div/span/a/h3/span').click()
